# %% [markdown]
# ## 假设总体规模$n = 10000$ 首先有下面两个公式
# <b> 1.无限总体的样本量公式 </b> <br>
# $$ n = \frac{Z^2 \cdot p \cdot (1 - p)}{E^2}  $$
# <del>
# <b> 2.有限总体的样本量公式(error) </b> <br>
# $$ n = \frac{Z^2 \cdot p \cdot (1 - p)}{\frac{E^2}{N} + \frac{Z^2 \cdot p \cdot (1-p)}{N}} $$
# </del>
# <b> 3.有限总体调整公式 </b>
# $$ n = \frac{n_0}{1 + \frac{n_0 - 1}{N}} $$
#
# 对于题目已经给出了$Z$(置信水平对应的Z值)和E(允许的误差范围) 用其计算出 $n$
#
# ## 现在考虑来进行优化,如果我们要抽取n个样本量
#
# 我们以10为一组 逐组抽取样本,如果发现当样本量为$x$时样本率为$p_x$ 则提前认为这批零件不合格
#
# 对于$p_0 = 10\%$的情况,使用蒙特卡洛进行大量多次数据模拟得出的 $p-n$图如下
#
# <img src=""> $~~~$ ← 一个图
#
# 以上得到的数据是 当$p_0 = 10\%$时且已有样本量为$n$时 有$98\%$的概率样本次品率会落入的范围上届
#
# 则对于上次的抽取 $p_x$ 就可以取这张表上的数据 因为$2\%$在一次实验中的概率很低,且这样做可以在$p_0 \neq 10\%$时快速结束抽样，以减少抽取的样本量,故采取上述策略优化抽取的样本量个数

# %%
import numpy as np
from scipy.stats import binomtest
import matplotlib.pyplot as plt

p0 = 0.1
p1 = 0.15
a = 0.05
# 不妨认为第二类错误概率β与α相同
b = 0.10

# 似然函数的边界
ceil, floor = np.log((1 - b) / a), np.log(b / (1 - a))


# 定义似然函数(对数化)
def L(x, n):
    return x * np.log(p1 / p0) + (n - x) * np.log((1 - p1) / (1 - p0))


total = 10000
Z_95 = 1.65
# 使用无限公式计算的
n1 = int(((Z_95 ** 2) * p0 * (1 - p0)) / (a ** 2))
# 有限调整
n2 = int(n1 / (1 + (n1 - 1) / total))

print("无限公式n =", n1, "有限公式n =", n2)


def extract(cnt: int) -> int:
    c0 = 0
    for i in range(cnt):
        sec = np.random.randint(0, data.size)
        if data[sec] == 0:
            c0 += 1
    return c0


def main():
    # 定义单次抽取的步长
    dc = 5

    c0, cnt = 0, 0
    if io:
        print(f"似然边界为{floor} ~ {ceil}")
    while cnt + dc <= n2:
        c0 += extract(dc)
        cnt += dc
        lv = L(c0, cnt)
        if io:
            print(f"{cnt}里有次品{c0},样本次品率{c0 / cnt},似然值为{lv}")
        if lv <= floor:
            if io:
                print(f"抽{cnt},次品{c0},接受这批零件")
            return True,cnt
        elif lv >= ceil:
            if io:
                print(f"抽{cnt},次品{c0},拒绝这批零件")
            return False,cnt
    if cnt < n2:
        c0 += extract(n2 - cnt)
        cnt = n2
    p = c0 / cnt
    res = binomtest(c0, cnt, p0, alternative="less")
    ret = False
    if res.pvalue > a:
        if io:
            print("抽完，但是接受这批零件")
        ret = True,cnt
    else:
        if io:
            print("抽完，但是拒绝这批零件")
    if io:
        print(f"{cnt}里有次品{c0},样本次品率{p},可能性概率为{res.pvalue}")
    return ret,cnt


if __name__ == "__main__":
    pz = 0.10
    pz_start = 0.01
    pz_end = 0.40

    OCx = []
    OCy = []

    ASNx = []
    ASNy = []

    io = False
    pi = pz_start;
    while pi < pz_end:
        data = np.array([0] * int(pi * total) + [1] * int((1 - pi) * total))
        np.random.shuffle(data)

        OCx.append(pi)
        ASNx.append(pi)

        ok = 0
        s = 0

        for i in range(100):
            flag,cnt = main()
            if flag:
                ok += 1
            s += cnt

        OCy.append(ok / 100)
        ASNy.append(s / 100)

        pi += 0.03

    plt.title("OC")
    plt.xlabel("real p0")
    plt.ylabel("accept p1")
    plt.yticks(ticks = np.arange(0, 1 + 0.05, 0.05))
    plt.plot(OCx, OCy)
    plt.axvline(p0, color = 'r', linestyle = "--")
    plt.axvline(p1, color = 'r', linestyle = "--")

    plt.figure()
    plt.title("ASN")
    plt.xlabel("real p0")
    plt.ylabel("average sample size n")
    plt.yticks([v for v in range(0,100,5)])
    plt.axvline(p0, color = 'r', linestyle = "--")
    plt.axvline(p1, color = 'r', linestyle = "--")
    plt.plot(ASNx, ASNy,color = "#B8860B")

    plt.show()
# Out:
# 无限公式n = 98 有限公式n = 97
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品2,样本次品率0.4,似然值为0.6394549746964825
# 10里有次品3,样本次品率0.3,似然值为0.8162864274448522
# 15里有次品4,样本次品率0.26666666666666666,似然值为0.9931178801932219
# 20里有次品5,样本次品率0.25,似然值为1.1699493329415918
# 25里有次品5,样本次品率0.2,似然值为0.8841572637418484
# 30里有次品5,样本次品率0.16666666666666666,似然值为0.5983651945421053
# 35里有次品5,样本次品率0.14285714285714285,似然值为0.31257312534236226
# 40里有次品6,样本次品率0.15,似然值为0.4894045780907317
# 45里有次品7,样本次品率0.15555555555555556,似然值为0.6662360308391015
# 50里有次品8,样本次品率0.16,似然值为0.843067483587471
# 55里有次品8,样本次品率0.14545454545454545,似然值为0.5572754143877279
# 60里有次品9,样本次品率0.15,似然值为0.7341068671360973
# 65里有次品11,样本次品率0.16923076923076924,似然值为1.3735618418325797
# 70里有次品11,样本次品率0.15714285714285714,似然值为1.0877697726328366
# 75里有次品12,样本次品率0.16,似然值为1.264601225381207
# 80里有次品12,样本次品率0.15,似然值为0.9788091561814634
# 85里有次品13,样本次品率0.15294117647058825,似然值为1.1556406089298328
# 90里有次品13,样本次品率0.14444444444444443,似然值为0.8698485397300892
# 95里有次品13,样本次品率0.1368421052631579,似然值为0.5840564705303466
# 100里有次品13,样本次品率0.13,似然值为0.29826440133060306
# 105里有次品13,样本次品率0.12380952380952381,似然值为0.012472332130860408
# 110里有次品13,样本次品率0.11818181818181818,似然值为-0.27331973706888313
# 115里有次品13,样本次品率0.11304347826086956,似然值为-0.5591118062686267
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品14,样本次品率0.112,似然值为-0.6680724227199999
# 130里有次品14,样本次品率0.1076923076923077,似然值为-0.9538644919197425
# 135里有次品17,样本次品率0.1259259259259259,似然值为0.1482140047248528
# 140里有次品18,样本次品率0.12857142857142856,似然值为0.3250454574732222
# 145里有次品18,样本次品率0.12413793103448276,似然值为0.039253388273478684
# 150里有次品18,样本次品率0.12,似然值为-0.24653868092626396
# 155里有次品18,样本次品率0.11612903225806452,似然值为-0.5323307501260075
# 160里有次品18,样本次品率0.1125,似然值为-0.818122819325751
# 165里有次品18,样本次品率0.10909090909090909,似然值为-1.1039148885254946
# 170里有次品19,样本次品率0.11176470588235295,似然值为-0.9270834357771234
# 175里有次品19,样本次品率0.10857142857142857,似然值为-1.212875504976867
# 180里有次品20,样本次品率0.1111111111111111,似然值为-1.0360440522284975
# 185里有次品20,样本次品率0.10810810810810811,似然值为-1.3218361214282393
# 190里有次品20,样本次品率0.10526315789473684,似然值为-1.6076281906279828
# 195里有次品21,样本次品率0.1076923076923077,似然值为-1.4307967378796143
# 200里有次品21,样本次品率0.105,似然值为-1.7165888070793578
# 205里有次品22,样本次品率0.1073170731707317,似然值为-1.5397573543309875
# 210里有次品22,样本次品率0.10476190476190476,似然值为-1.825549423530731
# 215里有次品22,样本次品率0.10232558139534884,似然值为-2.1113414927304746
# 220里有次品23,样本次品率0.10454545454545454,似然值为-1.934510039982106
# 225里有次品23,样本次品率0.10222222222222223,似然值为-2.220302109181848
# 230里有次品24,样本次品率0.10434782608695652,似然值为-2.0434706564334775
# 235里有次品24,样本次品率0.10212765957446808,似然值为-2.329262725633221
# 抽235,次品24,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品2,样本次品率0.1,似然值为-0.217921232902747
# 25里有次品3,样本次品率0.12,似然值为-0.04108978015437725
# 30里有次品3,样本次品率0.1,似然值为-0.32688184935412057
# 35里有次品4,样本次品率0.11428571428571428,似然值为-0.15005039660575092
# 40里有次品4,样本次品率0.1,似然值为-0.435842465805494
# 45里有次品5,样本次品率0.1111111111111111,似然值为-0.2590110130571244
# 50里有次品5,样本次品率0.1,似然值为-0.5448030822568675
# 55里有次品7,样本次品率0.12727272727272726,似然值为0.09465189243961492
# 60里有次品8,样本次品率0.13333333333333333,似然值为0.2714833451879848
# 65里有次品9,样本次品率0.13846153846153847,似然值为0.4483147979363542
# 70里有次品10,样本次品率0.14285714285714285,似然值为0.6251462506847245
# 75里有次品10,样本次品率0.13333333333333333,似然值为0.339354181484981
# 80里有次品10,样本次品率0.125,似然值为0.05356211228523833
# 85里有次品10,样本次品率0.11764705882352941,似然值为-0.2322299569145052
# 90里有次品10,样本次品率0.1111111111111111,似然值为-0.5180220261142487
# 95里有次品11,样本次品率0.11578947368421053,似然值为-0.3411905733658793
# 100里有次品11,样本次品率0.11,似然值为-0.6269826425656229
# 105里有次品12,样本次品率0.11428571428571428,似然值为-0.45015118981725255
# 110里有次品12,样本次品率0.10909090909090909,似然值为-0.7359432590169952
# 115里有次品12,样本次品率0.10434782608695652,似然值为-1.0217353282167387
# 120里有次品14,样本次品率0.11666666666666667,似然值为-0.38228035352025636
# 125里有次品14,样本次品率0.112,似然值为-0.6680724227199999
# 130里有次品14,样本次品率0.1076923076923077,似然值为-0.9538644919197425
# 135里有次品14,样本次品率0.1037037037037037,似然值为-1.239656561119486
# 140里有次品14,样本次品率0.1,似然值为-1.5254486303192287
# 145里有次品14,样本次品率0.09655172413793103,似然值为-1.8112406995189723
# 150里有次品16,样本次品率0.10666666666666667,似然值为-1.1717857248224899
# 155里有次品17,样本次品率0.10967741935483871,似然值为-0.9949542720741196
# 160里有次品20,样本次品率0.125,似然值为0.10712422457047666
# 165里有次品21,样本次品率0.12727272727272726,似然值为0.2839556773188452
# 170里有次品21,样本次品率0.12352941176470589,似然值为-0.001836391880898347
# 175里有次品21,样本次品率0.12,似然值为-0.2876284610806419
# 180里有次品21,样本次品率0.11666666666666667,似然值为-0.5734205302803836
# 185里有次品21,样本次品率0.11351351351351352,似然值为-0.8592125994801272
# 190里有次品21,样本次品率0.11052631578947368,似然值为-1.1450046686798707
# 195里有次品22,样本次品率0.11282051282051282,似然值为-0.9681732159315022
# 200里有次品22,样本次品率0.11,似然值为-1.2539652851312457
# 205里有次品22,样本次品率0.1073170731707317,似然值为-1.5397573543309875
# 210里有次品22,样本次品率0.10476190476190476,似然值为-1.825549423530731
# 215里有次品22,样本次品率0.10232558139534884,似然值为-2.1113414927304746
# 220里有次品23,样本次品率0.10454545454545454,似然值为-1.934510039982106
# 225里有次品23,样本次品率0.10222222222222223,似然值为-2.220302109181848
# 230里有次品23,样本次品率0.1,似然值为-2.5060941783815913
# 抽230,次品23,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品2,样本次品率0.13333333333333333,似然值为0.0678708362969962
# 20里有次品2,样本次品率0.1,似然值为-0.217921232902747
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品2,样本次品率0.05714285714285714,似然值为-1.0752974405019766
# 40里有次品3,样本次品率0.075,似然值为-0.898465987753607
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品5,样本次品率0.1,似然值为-0.5448030822568675
# 55里有次品7,样本次品率0.12727272727272726,似然值为0.09465189243961492
# 60里有次品7,样本次品率0.11666666666666667,似然值为-0.19114017676012818
# 65里有次品7,样本次品率0.1076923076923077,似然值为-0.47693224595987127
# 70里有次品7,样本次品率0.1,似然值为-0.7627243151596144
# 75里有次品8,样本次品率0.10666666666666667,似然值为-0.5858928624112449
# 80里有次品8,样本次品率0.1,似然值为-0.871684931610988
# 85里有次品8,样本次品率0.09411764705882353,似然值为-1.1574770008107316
# 90里有次品8,样本次品率0.08888888888888889,似然值为-1.4432690700104742
# 95里有次品9,样本次品率0.09473684210526316,似然值为-1.2664376172621052
# 100里有次品9,样本次品率0.09,似然值为-1.552229686461848
# 105里有次品9,样本次品率0.08571428571428572,似然值为-1.8380217556615914
# 110里有次品9,样本次品率0.08181818181818182,似然值为-2.123813824861334
# 115里有次品10,样本次品率0.08695652173913043,似然值为-1.9469823721129647
# 120里有次品10,样本次品率0.08333333333333333,似然值为-2.2327744413127073
# 125里有次品10,样本次品率0.08,似然值为-2.518566510512451
# 抽125,次品10,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品1,样本次品率0.05,似然值为-0.6805447548508599
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品2,样本次品率0.05714285714285714,似然值为-1.0752974405019766
# 40里有次品4,样本次品率0.1,似然值为-0.435842465805494
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品4,样本次品率0.08,似然值为-1.0074266042049802
# 55里有次品4,样本次品率0.07272727272727272,似然值为-1.2932186734047237
# 60里有次品6,样本次品率0.1,似然值为-0.6537636987082411
# 65里有次品8,样本次品率0.12307692307692308,似然值为-0.014308724011758756
# 70里有次品8,样本次品率0.11428571428571428,似然值为-0.30010079321150185
# 75里有次品8,样本次品率0.10666666666666667,似然值为-0.5858928624112449
# 80里有次品8,样本次品率0.1,似然值为-0.871684931610988
# 85里有次品10,样本次品率0.11764705882352941,似然值为-0.2322299569145052
# 90里有次品12,样本次品率0.13333333333333333,似然值为0.40722501778197717
# 95里有次品12,样本次品率0.12631578947368421,似然值为0.12143294858223364
# 100里有次品12,样本次品率0.12,似然值为-0.164359120617509
# 105里有次品12,样本次品率0.11428571428571428,似然值为-0.45015118981725255
# 110里有次品13,样本次品率0.11818181818181818,似然值为-0.27331973706888313
# 115里有次品13,样本次品率0.11304347826086956,似然值为-0.5591118062686267
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品14,样本次品率0.112,似然值为-0.6680724227199999
# 130里有次品15,样本次品率0.11538461538461539,似然值为-0.49124096997163047
# 135里有次品16,样本次品率0.11851851851851852,似然值为-0.31440951722326016
# 140里有次品18,样本次品率0.12857142857142856,似然值为0.3250454574732222
# 145里有次品18,样本次品率0.12413793103448276,似然值为0.039253388273478684
# 150里有次品18,样本次品率0.12,似然值为-0.24653868092626396
# 155里有次品19,样本次品率0.12258064516129032,似然值为-0.06970722817789454
# 160里有次品20,样本次品率0.125,似然值为0.10712422457047666
# 165里有次品20,样本次品率0.12121212121212122,似然值为-0.17866784462926688
# 170里有次品23,样本次品率0.13529411764705881,似然值为0.9234106520153258
# 175里有次品23,样本次品率0.13142857142857142,似然值为0.637618582815584
# 180里有次品23,样本次品率0.12777777777777777,似然值为0.3518265136158405
# 185里有次品24,样本次品率0.12972972972972974,似然值为0.5286579663642108
# 190里有次品25,样本次品率0.13157894736842105,似然值为0.7054894191125811
# 195里有次品25,样本次品率0.1282051282051282,似然值为0.4196973499128376
# 200里有次品25,样本次品率0.125,似然值为0.13390528071309404
# 205里有次品25,样本次品率0.12195121951219512,似然值为-0.1518867884866495
# 210里有次品25,样本次品率0.11904761904761904,似然值为-0.43767885768639303
# 215里有次品25,样本次品率0.11627906976744186,似然值为-0.7234709268861348
# 220里有次品25,样本次品率0.11363636363636363,似然值为-1.0092629960858783
# 225里有次品25,样本次品率0.1111111111111111,似然值为-1.2950550652856219
# 230里有次品25,样本次品率0.10869565217391304,似然值为-1.5808471344853654
# 235里有次品25,样本次品率0.10638297872340426,似然值为-1.866639203685109
# 240里有次品26,样本次品率0.10833333333333334,似然值为-1.6898077509367386
# 245里有次品28,样本次品率0.11428571428571428,似然值为-1.0503527762402562
# 250里有次品28,样本次品率0.112,似然值为-1.3361448454399998
# 255里有次品29,样本次品率0.11372549019607843,似然值为-1.1593133926916295
# 260里有次品29,样本次品率0.11153846153846154,似然值为-1.445105461891373
# 265里有次品29,样本次品率0.10943396226415095,似然值为-1.7308975310911165
# 270里有次品29,样本次品率0.10740740740740741,似然值为-2.01668960029086
# 275里有次品29,样本次品率0.10545454545454545,似然值为-2.302481669490602
# 抽275,次品29,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品2,样本次品率0.1,似然值为-0.217921232902747
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品3,样本次品率0.08571428571428572,似然值为-0.6126739185538637
# 40里有次品3,样本次品率0.075,似然值为-0.898465987753607
# 45里有次品5,样本次品率0.1111111111111111,似然值为-0.2590110130571244
# 50里有次品5,样本次品率0.1,似然值为-0.5448030822568675
# 55里有次品5,样本次品率0.09090909090909091,似然值为-0.8305951514566106
# 60里有次品6,样本次品率0.1,似然值为-0.6537636987082411
# 65里有次品6,样本次品率0.09230769230769231,似然值为-0.9395557679079842
# 70里有次品7,样本次品率0.1,似然值为-0.7627243151596144
# 75里有次品9,样本次品率0.12,似然值为-0.12326934046313198
# 80里有次品9,样本次品率0.1125,似然值为-0.4090614096628755
# 85里有次品9,样本次品率0.10588235294117647,似然值为-0.6948534788626182
# 90里有次品9,样本次品率0.1,似然值为-0.9806455480623617
# 95里有次品9,样本次品率0.09473684210526316,似然值为-1.2664376172621052
# 100里有次品9,样本次品率0.09,似然值为-1.552229686461848
# 105里有次品9,样本次品率0.08571428571428572,似然值为-1.8380217556615914
# 110里有次品9,样本次品率0.08181818181818182,似然值为-2.123813824861334
# 115里有次品9,样本次品率0.0782608695652174,似然值为-2.4096058940610776
# 抽115,次品9,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品2,样本次品率0.2,似然值为0.35366290549673934
# 15里有次品3,样本次品率0.2,似然值为0.530494358245109
# 20里有次品3,样本次品率0.15,似然值为0.24470228904536584
# 25里有次品5,样本次品率0.2,似然值为0.8841572637418484
# 30里有次品5,样本次品率0.16666666666666666,似然值为0.5983651945421053
# 35里有次品5,样本次品率0.14285714285714285,似然值为0.31257312534236226
# 40里有次品7,样本次品率0.175,似然值为0.9520281000388446
# 45里有次品7,样本次品率0.15555555555555556,似然值为0.6662360308391015
# 50里有次品7,样本次品率0.14,似然值为0.380443961639358
# 55里有次品7,样本次品率0.12727272727272726,似然值为0.09465189243961492
# 60里有次品7,样本次品率0.11666666666666667,似然值为-0.19114017676012818
# 65里有次品7,样本次品率0.1076923076923077,似然值为-0.47693224595987127
# 70里有次品7,样本次品率0.1,似然值为-0.7627243151596144
# 75里有次品7,样本次品率0.09333333333333334,似然值为-1.048516384359358
# 80里有次品8,样本次品率0.1,似然值为-0.871684931610988
# 85里有次品10,样本次品率0.11764705882352941,似然值为-0.2322299569145052
# 90里有次品11,样本次品率0.12222222222222222,似然值为-0.05539850416613579
# 95里有次品11,样本次品率0.11578947368421053,似然值为-0.3411905733658793
# 100里有次品11,样本次品率0.11,似然值为-0.6269826425656229
# 105里有次品13,样本次品率0.12380952380952381,似然值为0.012472332130860408
# 110里有次品15,样本次品率0.13636363636363635,似然值为0.6519273068273428
# 115里有次品15,样本次品率0.13043478260869565,似然值为0.36613523762759925
# 120里有次品15,样本次品率0.125,似然值为0.08034316842785572
# 125里有次品16,样本次品率0.128,似然值为0.257174621176226
# 130里有次品17,样本次品率0.13076923076923078,似然值为0.43400607392459634
# 135里有次品17,样本次品率0.1259259259259259,似然值为0.1482140047248528
# 140里有次品17,样本次品率0.12142857142857143,似然值为-0.13757806447488985
# 145里有次品17,样本次品率0.11724137931034483,似然值为-0.4233701336746334
# 150里有次品20,样本次品率0.13333333333333333,似然值为0.678708362969962
# 155里有次品20,样本次品率0.12903225806451613,似然值为0.3929162937702193
# 160里有次品21,样本次品率0.13125,似然值为0.5697477465185878
# 165里有次品21,样本次品率0.12727272727272726,似然值为0.2839556773188452
# 170里有次品21,样本次品率0.12352941176470589,似然值为-0.001836391880898347
# 175里有次品21,样本次品率0.12,似然值为-0.2876284610806419
# 180里有次品22,样本次品率0.12222222222222222,似然值为-0.11079700833227157
# 185里有次品22,样本次品率0.11891891891891893,似然值为-0.3965890775320151
# 190里有次品24,样本次品率0.12631578947368421,似然值为0.24286589716446727
# 195里有次品25,样本次品率0.1282051282051282,似然值为0.4196973499128376
# 200里有次品26,样本次品率0.13,似然值为0.5965288026612061
# 205里有次品27,样本次品率0.13170731707317074,似然值为0.7733602554095764
# 210里有次品27,样本次品率0.12857142857142856,似然值为0.48756818620983466
# 215里有次品29,样本次品率0.13488372093023257,似然值为1.1270231609063153
# 220里有次品29,样本次品率0.1318181818181818,似然值为0.8412310917065717
# 225里有次品29,样本次品率0.1288888888888889,似然值为0.55543902250683
# 230里有次品30,样本次品率0.13043478260869565,似然值为0.7322704752551985
# 235里有次品30,样本次品率0.1276595744680851,似然值为0.44647840605545497
# 240里有次品30,样本次品率0.125,似然值为0.16068633685571143
# 245里有次品31,样本次品率0.12653061224489795,似然值为0.3375177896040835
# 250里有次品32,样本次品率0.128,似然值为0.514349242352452
# 255里有次品32,样本次品率0.12549019607843137,似然值为0.22855717315270851
# 260里有次品33,样本次品率0.12692307692307692,似然值为0.4053886259010788
# 265里有次品33,样本次品率0.12452830188679245,似然值为0.11959655670133529
# 270里有次品33,样本次品率0.12222222222222222,似然值为-0.16619551249840825
# 275里有次品34,样本次品率0.12363636363636364,似然值为0.010635940249962061
# 280里有次品34,样本次品率0.12142857142857143,似然值为-0.2751561289497797
# 285里有次品35,样本次品率0.12280701754385964,似然值为-0.09832467620141117
# 290里有次品36,样本次品率0.12413793103448276,似然值为0.07850677654695737
# 295里有次品36,样本次品率0.12203389830508475,似然值为-0.2072852926527844
# 300里有次品37,样本次品率0.12333333333333334,似然值为-0.030453839904415858
# 305里有次品37,样本次品率0.12131147540983607,似然值为-0.3162459091041594
# 310里有次品37,样本次品率0.11935483870967742,似然值为-0.6020379783039029
# 315里有次品37,样本次品率0.11746031746031746,似然值为-0.8878300475036465
# 320里有次品37,样本次品率0.115625,似然值为-1.1736221167033882
# 325里有次品38,样本次品率0.11692307692307692,似然值为-0.9967906639550161
# 330里有次品39,样本次品率0.11818181818181818,似然值为-0.8199592112066494
# 335里有次品40,样本次品率0.11940298507462686,似然值为-0.6431277584582773
# 340里有次品40,样本次品率0.11764705882352941,似然值为-0.9289198276580208
# 345里有次品40,样本次品率0.11594202898550725,似然值为-1.2147118968577644
# 350里有次品42,样本次品率0.12,似然值为-0.5752569221612838
# 355里有次品43,样本次品率0.12112676056338029,似然值为-0.39842546941291346
# 360里有次品45,样本次品率0.125,似然值为0.24102950528356715
# 365里有次品45,样本次品率0.1232876712328767,似然值为-0.04476256391617639
# 370里有次品45,样本次品率0.12162162162162163,似然值为-0.3305546331159199
# 375里有次品45,样本次品率0.12,似然值为-0.6163467023156599
# 380里有次品45,样本次品率0.11842105263157894,似然值为-0.9021387715154034
# 385里有次品45,样本次品率0.11688311688311688,似然值为-1.187930840715147
# 390里有次品45,样本次品率0.11538461538461539,似然值为-1.4737229099148905
# 395里有次品45,样本次品率0.11392405063291139,似然值为-1.759514979114634
# 400里有次品45,样本次品率0.1125,似然值为-2.0453070483143776
# 405里有次品45,样本次品率0.1111111111111111,似然值为-2.331099117514121
# 抽405,次品45,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品2,样本次品率0.13333333333333333,似然值为0.0678708362969962
# 20里有次品2,样本次品率0.1,似然值为-0.217921232902747
# 25里有次品3,样本次品率0.12,似然值为-0.04108978015437725
# 30里有次品3,样本次品率0.1,似然值为-0.32688184935412057
# 35里有次品4,样本次品率0.11428571428571428,似然值为-0.15005039660575092
# 40里有次品5,样本次品率0.125,似然值为0.026781056142619164
# 45里有次品5,样本次品率0.1111111111111111,似然值为-0.2590110130571244
# 50里有次品6,样本次品率0.12,似然值为-0.0821795603087545
# 55里有次品6,样本次品率0.10909090909090909,似然值为-0.3679716295084976
# 60里有次品6,样本次品率0.1,似然值为-0.6537636987082411
# 65里有次品6,样本次品率0.09230769230769231,似然值为-0.9395557679079842
# 70里有次品6,样本次品率0.08571428571428572,似然值为-1.2253478371077273
# 75里有次品6,样本次品率0.08,似然值为-1.5111399063074704
# 80里有次品6,样本次品率0.075,似然值为-1.796931975507214
# 85里有次品6,样本次品率0.07058823529411765,似然值为-2.0827240447069566
# 90里有次品7,样本次品率0.07777777777777778,似然值为-1.9058925919585876
# 95里有次品7,样本次品率0.07368421052631578,似然值为-2.1916846611583303
# 100里有次品8,样本次品率0.08,似然值为-2.0148532084099604
# 105里有次品8,样本次品率0.0761904761904762,似然值为-2.300645277609704
# 抽105,次品8,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品3,样本次品率0.3,似然值为0.8162864274448522
# 15里有次品3,样本次品率0.2,似然值为0.530494358245109
# 20里有次品5,样本次品率0.25,似然值为1.1699493329415918
# 25里有次品6,样本次品率0.24,似然值为1.3467807856899614
# 30里有次品6,样本次品率0.2,似然值为1.060988716490218
# 35里有次品6,样本次品率0.17142857142857143,似然值为0.775196647290475
# 40里有次品6,样本次品率0.15,似然值为0.4894045780907317
# 45里有次品6,样本次品率0.13333333333333333,似然值为0.20361250889098859
# 50里有次品7,样本次品率0.14,似然值为0.380443961639358
# 55里有次品7,样本次品率0.12727272727272726,似然值为0.09465189243961492
# 60里有次品8,样本次品率0.13333333333333333,似然值为0.2714833451879848
# 65里有次品9,样本次品率0.13846153846153847,似然值为0.4483147979363542
# 70里有次品10,样本次品率0.14285714285714285,似然值为0.6251462506847245
# 75里有次品10,样本次品率0.13333333333333333,似然值为0.339354181484981
# 80里有次品10,样本次品率0.125,似然值为0.05356211228523833
# 85里有次品10,样本次品率0.11764705882352941,似然值为-0.2322299569145052
# 90里有次品11,样本次品率0.12222222222222222,似然值为-0.05539850416613579
# 95里有次品11,样本次品率0.11578947368421053,似然值为-0.3411905733658793
# 100里有次品11,样本次品率0.11,似然值为-0.6269826425656229
# 105里有次品11,样本次品率0.10476190476190476,似然值为-0.9127747117653655
# 110里有次品11,样本次品率0.1,似然值为-1.198566780965109
# 115里有次品12,样本次品率0.10434782608695652,似然值为-1.0217353282167387
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品13,样本次品率0.104,似然值为-1.1306959446681129
# 130里有次品13,样本次品率0.1,似然值为-1.4164880138678555
# 135里有次品13,样本次品率0.0962962962962963,似然值为-1.702280083067599
# 140里有次品13,样本次品率0.09285714285714286,似然值为-1.9880721522673426
# 145里有次品13,样本次品率0.0896551724137931,似然值为-2.2738642214670852
# 抽145,次品13,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品1,样本次品率0.05,似然值为-0.6805447548508599
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品3,样本次品率0.1,似然值为-0.32688184935412057
# 35里有次品3,样本次品率0.08571428571428572,似然值为-0.6126739185538637
# 40里有次品3,样本次品率0.075,似然值为-0.898465987753607
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品4,样本次品率0.08,似然值为-1.0074266042049802
# 55里有次品4,样本次品率0.07272727272727272,似然值为-1.2932186734047237
# 60里有次品4,样本次品率0.06666666666666667,似然值为-1.5790107426044668
# 65里有次品4,样本次品率0.06153846153846154,似然值为-1.86480281180421
# 70里有次品4,样本次品率0.05714285714285714,似然值为-2.1505948810039532
# 75里有次品4,样本次品率0.05333333333333334,似然值为-2.4363869502036968
# 抽75,次品4,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品1,样本次品率0.05,似然值为-0.6805447548508599
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品2,样本次品率0.05714285714285714,似然值为-1.0752974405019766
# 40里有次品3,样本次品率0.075,似然值为-0.898465987753607
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品4,样本次品率0.08,似然值为-1.0074266042049802
# 55里有次品5,样本次品率0.09090909090909091,似然值为-0.8305951514566106
# 60里有次品7,样本次品率0.11666666666666667,似然值为-0.19114017676012818
# 65里有次品9,样本次品率0.13846153846153847,似然值为0.4483147979363542
# 70里有次品9,样本次品率0.12857142857142856,似然值为0.1625227287366111
# 75里有次品9,样本次品率0.12,似然值为-0.12326934046313198
# 80里有次品10,样本次品率0.125,似然值为0.05356211228523833
# 85里有次品10,样本次品率0.11764705882352941,似然值为-0.2322299569145052
# 90里有次品10,样本次品率0.1111111111111111,似然值为-0.5180220261142487
# 95里有次品11,样本次品率0.11578947368421053,似然值为-0.3411905733658793
# 100里有次品12,样本次品率0.12,似然值为-0.164359120617509
# 105里有次品12,样本次品率0.11428571428571428,似然值为-0.45015118981725255
# 110里有次品13,样本次品率0.11818181818181818,似然值为-0.27331973706888313
# 115里有次品13,样本次品率0.11304347826086956,似然值为-0.5591118062686267
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品13,样本次品率0.104,似然值为-1.1306959446681129
# 130里有次品13,样本次品率0.1,似然值为-1.4164880138678555
# 135里有次品13,样本次品率0.0962962962962963,似然值为-1.702280083067599
# 140里有次品14,样本次品率0.1,似然值为-1.5254486303192287
# 145里有次品14,样本次品率0.09655172413793103,似然值为-1.8112406995189723
# 150里有次品16,样本次品率0.10666666666666667,似然值为-1.1717857248224899
# 155里有次品16,样本次品率0.1032258064516129,似然值为-1.4575777940222334
# 160里有次品16,样本次品率0.1,似然值为-1.743369863221976
# 165里有次品16,样本次品率0.09696969696969697,似然值为-2.0291619324217196
# 170里有次品16,样本次品率0.09411764705882353,似然值为-2.314954001621463
# 抽170,次品16,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品0,样本次品率0.0,似然值为-0.8573762075992295
# 20里有次品1,样本次品率0.05,似然值为-0.6805447548508599
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品3,样本次品率0.08571428571428572,似然值为-0.6126739185538637
# 40里有次品3,样本次品率0.075,似然值为-0.898465987753607
# 45里有次品3,样本次品率0.06666666666666667,似然值为-1.18425805695335
# 50里有次品3,样本次品率0.06,似然值为-1.4700501261530932
# 55里有次品3,样本次品率0.05454545454545454,似然值为-1.7558421953528363
# 60里有次品3,样本次品率0.05,似然值为-2.04163426455258
# 65里有次品3,样本次品率0.046153846153846156,似然值为-2.3274263337523227
# 抽65,次品3,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品0,样本次品率0.0,似然值为-0.8573762075992295
# 20里有次品0,样本次品率0.0,似然值为-1.1431682767989728
# 25里有次品1,样本次品率0.04,似然值为-0.9663368240506032
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品2,样本次品率0.05714285714285714,似然值为-1.0752974405019766
# 40里有次品3,样本次品率0.075,似然值为-0.898465987753607
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品4,样本次品率0.08,似然值为-1.0074266042049802
# 55里有次品4,样本次品率0.07272727272727272,似然值为-1.2932186734047237
# 60里有次品4,样本次品率0.06666666666666667,似然值为-1.5790107426044668
# 65里有次品4,样本次品率0.06153846153846154,似然值为-1.86480281180421
# 70里有次品4,样本次品率0.05714285714285714,似然值为-2.1505948810039532
# 75里有次品4,样本次品率0.05333333333333334,似然值为-2.4363869502036968
# 抽75,次品4,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品3,样本次品率0.2,似然值为0.530494358245109
# 20里有次品3,样本次品率0.15,似然值为0.24470228904536584
# 25里有次品5,样本次品率0.2,似然值为0.8841572637418484
# 30里有次品5,样本次品率0.16666666666666666,似然值为0.5983651945421053
# 35里有次品5,样本次品率0.14285714285714285,似然值为0.31257312534236226
# 40里有次品6,样本次品率0.15,似然值为0.4894045780907317
# 45里有次品8,样本次品率0.17777777777777778,似然值为1.128859552787214
# 50里有次品8,样本次品率0.16,似然值为0.843067483587471
# 55里有次品9,样本次品率0.16363636363636364,似然值为1.0198989363358408
# 60里有次品9,样本次品率0.15,似然值为0.7341068671360973
# 65里有次品9,样本次品率0.13846153846153847,似然值为0.4483147979363542
# 70里有次品9,样本次品率0.12857142857142856,似然值为0.1625227287366111
# 75里有次品9,样本次品率0.12,似然值为-0.12326934046313198
# 80里有次品9,样本次品率0.1125,似然值为-0.4090614096628755
# 85里有次品9,样本次品率0.10588235294117647,似然值为-0.6948534788626182
# 90里有次品9,样本次品率0.1,似然值为-0.9806455480623617
# 95里有次品9,样本次品率0.09473684210526316,似然值为-1.2664376172621052
# 100里有次品9,样本次品率0.09,似然值为-1.552229686461848
# 105里有次品9,样本次品率0.08571428571428572,似然值为-1.8380217556615914
# 110里有次品11,样本次品率0.1,似然值为-1.198566780965109
# 115里有次品11,样本次品率0.09565217391304348,似然值为-1.4843588501648517
# 120里有次品11,样本次品率0.09166666666666666,似然值为-1.7701509193645952
# 125里有次品11,样本次品率0.088,似然值为-2.0559429885643388
# 130里有次品13,样本次品率0.1,似然值为-1.4164880138678555
# 135里有次品13,样本次品率0.0962962962962963,似然值为-1.702280083067599
# 140里有次品13,样本次品率0.09285714285714286,似然值为-1.9880721522673426
# 145里有次品13,样本次品率0.0896551724137931,似然值为-2.2738642214670852
# 抽145,次品13,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品0,样本次品率0.0,似然值为-0.8573762075992295
# 20里有次品0,样本次品率0.0,似然值为-1.1431682767989728
# 25里有次品0,样本次品率0.0,似然值为-1.428960345998716
# 30里有次品1,样本次品率0.03333333333333333,似然值为-1.2521288932503463
# 35里有次品2,样本次品率0.05714285714285714,似然值为-1.0752974405019766
# 40里有次品2,样本次品率0.05,似然值为-1.3610895097017197
# 45里有次品3,样本次品率0.06666666666666667,似然值为-1.18425805695335
# 50里有次品3,样本次品率0.06,似然值为-1.4700501261530932
# 55里有次品3,样本次品率0.05454545454545454,似然值为-1.7558421953528363
# 60里有次品4,样本次品率0.06666666666666667,似然值为-1.5790107426044668
# 65里有次品5,样本次品率0.07692307692307693,似然值为-1.4021792898560967
# 70里有次品5,样本次品率0.07142857142857142,似然值为-1.6879713590558403
# 75里有次品5,样本次品率0.06666666666666667,似然值为-1.973763428255583
# 80里有次品6,样本次品率0.075,似然值为-1.796931975507214
# 85里有次品6,样本次品率0.07058823529411765,似然值为-2.0827240447069566
# 90里有次品7,样本次品率0.07777777777777778,似然值为-1.9058925919585876
# 95里有次品7,样本次品率0.07368421052631578,似然值为-2.1916846611583303
# 100里有次品7,样本次品率0.07,似然值为-2.477476730358074
# 抽100,次品7,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品2,样本次品率0.1,似然值为-0.217921232902747
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品2,样本次品率0.05714285714285714,似然值为-1.0752974405019766
# 40里有次品2,样本次品率0.05,似然值为-1.3610895097017197
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品5,样本次品率0.1,似然值为-0.5448030822568675
# 55里有次品6,样本次品率0.10909090909090909,似然值为-0.3679716295084976
# 60里有次品6,样本次品率0.1,似然值为-0.6537636987082411
# 65里有次品6,样本次品率0.09230769230769231,似然值为-0.9395557679079842
# 70里有次品7,样本次品率0.1,似然值为-0.7627243151596144
# 75里有次品8,样本次品率0.10666666666666667,似然值为-0.5858928624112449
# 80里有次品9,样本次品率0.1125,似然值为-0.4090614096628755
# 85里有次品10,样本次品率0.11764705882352941,似然值为-0.2322299569145052
# 90里有次品10,样本次品率0.1111111111111111,似然值为-0.5180220261142487
# 95里有次品10,样本次品率0.10526315789473684,似然值为-0.8038140953139914
# 100里有次品10,样本次品率0.1,似然值为-1.089606164513735
# 105里有次品11,样本次品率0.10476190476190476,似然值为-0.9127747117653655
# 110里有次品12,样本次品率0.10909090909090909,似然值为-0.7359432590169952
# 115里有次品12,样本次品率0.10434782608695652,似然值为-1.0217353282167387
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品15,样本次品率0.12,似然值为-0.20544890077188693
# 130里有次品16,样本次品率0.12307692307692308,似然值为-0.02861744802351751
# 135里有次品18,样本次品率0.13333333333333333,似然值为0.6108375266729658
# 140里有次品18,样本次品率0.12857142857142856,似然值为0.3250454574732222
# 145里有次品19,样本次品率0.1310344827586207,似然值为0.5018769102215925
# 150里有次品20,样本次品率0.13333333333333333,似然值为0.678708362969962
# 155里有次品21,样本次品率0.13548387096774195,似然值为0.8555398157183314
# 160里有次品22,样本次品率0.1375,似然值为1.0323712684667008
# 165里有次品22,样本次品率0.13333333333333333,似然值为0.7465791992669573
# 170里有次品23,样本次品率0.13529411764705881,似然值为0.9234106520153258
# 175里有次品24,样本次品率0.13714285714285715,似然值为1.1002421047636979
# 180里有次品25,样本次品率0.1388888888888889,似然值为1.2770735575120664
# 185里有次品25,样本次品率0.13513513513513514,似然值为0.9912814883123229
# 190里有次品28,样本次品率0.14736842105263157,似然值为2.093359984956919
# 195里有次品29,样本次品率0.14871794871794872,似然值为2.2701914377052876
# 200里有次品29,样本次品率0.145,似然值为1.9843993685055459
# 205里有次品29,样本次品率0.14146341463414633,似然值为1.6986072993058023
# 210里有次品29,样本次品率0.1380952380952381,似然值为1.4128152301060588
# 215里有次品29,样本次品率0.13488372093023257,似然值为1.1270231609063153
# 220里有次品29,样本次品率0.1318181818181818,似然值为0.8412310917065717
# 225里有次品30,样本次品率0.13333333333333333,似然值为1.018062544454942
# 230里有次品30,样本次品率0.13043478260869565,似然值为0.7322704752551985
# 235里有次品30,样本次品率0.1276595744680851,似然值为0.44647840605545497
# 240里有次品30,样本次品率0.125,似然值为0.16068633685571143
# 245里有次品32,样本次品率0.1306122448979592,似然值为0.8001413115521956
# 250里有次品33,样本次品率0.132,似然值为0.9769727643005641
# 255里有次品33,样本次品率0.12941176470588237,似然值为0.6911806951008206
# 260里有次品34,样本次品率0.13076923076923078,似然值为0.8680121478491927
# 265里有次品37,样本次品率0.13962264150943396,似然值为1.9700906444937853
# 270里有次品37,样本次品率0.13703703703703704,似然值为1.6842985752940436
# 275里有次品37,样本次品率0.13454545454545455,似然值为1.3985065060943
# 280里有次品38,样本次品率0.1357142857142857,似然值为1.5753379588426704
# 285里有次品39,样本次品率0.1368421052631579,似然值为1.7521694115910407
# 290里有次品39,样本次品率0.13448275862068965,似然值为1.4663773423912971
# 295里有次品39,样本次品率0.13220338983050847,似然值为1.1805852731915536
# 300里有次品40,样本次品率0.13333333333333333,似然值为1.357416725939924
# 305里有次品40,样本次品率0.13114754098360656,似然值为1.0716246567401821
# 310里有次品40,样本次品率0.12903225806451613,似然值为0.7858325875404386
# 315里有次品42,样本次品率0.13333333333333333,似然值为1.4252875622369192
# 320里有次品42,样本次品率0.13125,似然值为1.1394954930371757
# 325里有次品42,样本次品率0.12923076923076923,似然值为0.8537034238374339
# 330里有次品42,样本次品率0.12727272727272726,似然值为0.5679113546376904
# 335里有次品43,样本次品率0.12835820895522387,似然值为0.7447428073860607
# 340里有次品43,样本次品率0.1264705882352941,似然值为0.45895073818631715
# 345里有次品44,样本次品率0.12753623188405797,似然值为0.6357821909346839
# 350里有次品44,样本次品率0.12571428571428572,似然值为0.3499901217349404
# 355里有次品45,样本次品率0.1267605633802817,似然值为0.5268215744833107
# 360里有次品45,样本次品率0.125,似然值为0.24102950528356715
# 365里有次品46,样本次品率0.12602739726027398,似然值为0.41786095803193746
# 370里有次品46,样本次品率0.12432432432432433,似然值为0.13206888883219392
# 375里有次品46,样本次品率0.12266666666666666,似然值为-0.15372318036754962
# 380里有次品46,样本次品率0.12105263157894737,似然值为-0.43951524956729315
# 385里有次品47,样本次品率0.12207792207792208,似然值为-0.2626837968189193
# 390里有次品47,样本次品率0.12051282051282051,似然值为-0.5484758660186628
# 395里有次品48,样本次品率0.12151898734177215,似然值为-0.3716444132702925
# 400里有次品50,样本次品率0.125,似然值为0.2678105614261881
# 405里有次品51,样本次品率0.1259259259259259,似然值为0.4446420141745584
# 410里有次品53,样本次品率0.12926829268292683,似然值为1.084096988871039
# 415里有次品53,样本次品率0.12771084337349398,似然值为0.7983049196712955
# 420里有次品53,样本次品率0.1261904761904762,似然值为0.5125128504715519
# 425里有次品54,样本次品率0.12705882352941175,似然值为0.6893443032199258
# 430里有次品56,样本次品率0.13023255813953488,似然值为1.3287992779164064
# 435里有次品56,样本次品率0.12873563218390804,似然值为1.0430072087166629
# 440里有次品57,样本次品率0.12954545454545455,似然值为1.2198386614650332
# 445里有次品58,样本次品率0.1303370786516854,似然值为1.3966701142134035
# 450里有次品58,样本次品率0.1288888888888889,似然值为1.11087804501366
# 455里有次品60,样本次品率0.13186813186813187,似然值为1.7503330197101405
# 460里有次品60,样本次品率0.13043478260869565,似然值为1.464540950510397
# 465里有次品60,样本次品率0.12903225806451613,似然值为1.1787488813106535
# 470里有次品61,样本次品率0.12978723404255318,似然值为1.3555803340590273
# 475里有次品61,样本次品率0.12842105263157894,似然值为1.0697882648592838
# 480里有次品62,样本次品率0.12916666666666668,似然值为1.246619717607654
# 485里有次品62,样本次品率0.12783505154639174,似然值为0.9608276484079106
# 490里有次品63,样本次品率0.12857142857142856,似然值为1.1376591011562773
# 495里有次品63,样本次品率0.12727272727272726,似然值为0.8518670319565338
# 500里有次品63,样本次品率0.126,似然值为0.5660749627567938
# 505里有次品65,样本次品率0.12871287128712872,似然值为1.2055299374532744
# 510里有次品65,样本次品率0.12745098039215685,似然值为0.9197378682535309
# 515里有次品65,样本次品率0.1262135922330097,似然值为0.6339457990537873
# 520里有次品67,样本次品率0.12884615384615383,似然值为1.273400773750268
# 525里有次品68,样本次品率0.1295238095238095,似然值为1.4502322264986418
# 530里有次品69,样本次品率0.13018867924528302,似然值为1.6270636792470121
# 535里有次品69,样本次品率0.12897196261682242,似然值为1.3412716100472686
# 540里有次品70,样本次品率0.12962962962962962,似然值为1.5181030627956353
# 545里有次品70,样本次品率0.12844036697247707,似然值为1.2323109935958918
# 550里有次品70,样本次品率0.12727272727272726,似然值为0.9465189243961518
# 555里有次品70,样本次品率0.12612612612612611,似然值为0.6607268551964083
# 560里有次品70,样本次品率0.125,似然值为0.37493478599666474
# 565里有次品70,样本次品率0.12389380530973451,似然值为0.0891427167969212
# 570里有次品70,样本次品率0.12280701754385964,似然值为-0.19664935240282233
# 575里有次品70,样本次品率0.12173913043478261,似然值为-0.48244142160256587
# 580里有次品70,样本次品率0.1206896551724138,似然值为-0.7682334908023094
# 585里有次品71,样本次品率0.12136752136752137,似然值为-0.5914020380539391
# 590里有次品71,样本次品率0.12033898305084746,似然值为-0.8771941072536826
# 595里有次品72,样本次品率0.12100840336134454,似然值为-0.7003626545053123
# 600里有次品72,样本次品率0.12,似然值为-0.9861547237050559
# 605里有次品72,样本次品率0.11900826446280992,似然值为-1.2719467929047994
# 610里有次品73,样本次品率0.11967213114754098,似然值为-1.0951153401564326
# 615里有次品73,样本次品率0.11869918699186992,似然值为-1.3809074093561726
# 620里有次品74,样本次品率0.11935483870967742,似然值为-1.2040759566078059
# 625里有次品74,样本次品率0.1184,似然值为-1.4898680258075494
# 630里有次品74,样本次品率0.11746031746031746,似然值为-1.775660095007293
# 635里有次品74,样本次品率0.11653543307086614,似然值为-2.061452164207033
# 640里有次品76,样本次品率0.11875,似然值为-1.4219971895105523
# 645里有次品76,样本次品率0.11782945736434108,似然值为-1.7077892587102959
# 650里有次品77,样本次品率0.11846153846153847,似然值为-1.5309578059619255
# 655里有次品77,样本次品率0.11755725190839694,似然值为-1.816749875161669
# 660里有次品78,样本次品率0.11818181818181818,似然值为-1.6399184224132988
# 665里有次品78,样本次品率0.11729323308270677,似然值为-1.9257104916130423
# 670里有次品79,样本次品率0.11791044776119403,似然值为-1.748879038864672
# 675里有次品79,样本次品率0.11703703703703704,似然值为-2.0346711080644155
# 680里有次品79,样本次品率0.1161764705882353,似然值为-2.320463177264159
# 抽680,次品79,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品1,样本次品率0.05,似然值为-0.6805447548508599
# 25里有次品1,样本次品率0.04,似然值为-0.9663368240506032
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品3,样本次品率0.08571428571428572,似然值为-0.6126739185538637
# 40里有次品4,样本次品率0.1,似然值为-0.435842465805494
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品4,样本次品率0.08,似然值为-1.0074266042049802
# 55里有次品4,样本次品率0.07272727272727272,似然值为-1.2932186734047237
# 60里有次品5,样本次品率0.08333333333333333,似然值为-1.1163872206563537
# 65里有次品5,样本次品率0.07692307692307693,似然值为-1.4021792898560967
# 70里有次品5,样本次品率0.07142857142857142,似然值为-1.6879713590558403
# 75里有次品6,样本次品率0.08,似然值为-1.5111399063074704
# 80里有次品6,样本次品率0.075,似然值为-1.796931975507214
# 85里有次品6,样本次品率0.07058823529411765,似然值为-2.0827240447069566
# 90里有次品7,样本次品率0.07777777777777778,似然值为-1.9058925919585876
# 95里有次品8,样本次品率0.08421052631578947,似然值为-1.7290611392102178
# 100里有次品9,样本次品率0.09,似然值为-1.552229686461848
# 105里有次品10,样本次品率0.09523809523809523,似然值为-1.3753982337134776
# 110里有次品12,样本次品率0.10909090909090909,似然值为-0.7359432590169952
# 115里有次品12,样本次品率0.10434782608695652,似然值为-1.0217353282167387
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品13,样本次品率0.104,似然值为-1.1306959446681129
# 130里有次品14,样本次品率0.1076923076923077,似然值为-0.9538644919197425
# 135里有次品15,样本次品率0.1111111111111111,似然值为-0.7770330391713731
# 140里有次品16,样本次品率0.11428571428571428,似然值为-0.6002015864230037
# 145里有次品17,样本次品率0.11724137931034483,似然值为-0.4233701336746334
# 150里有次品18,样本次品率0.12,似然值为-0.24653868092626396
# 155里有次品18,样本次品率0.11612903225806452,似然值为-0.5323307501260075
# 160里有次品18,样本次品率0.1125,似然值为-0.818122819325751
# 165里有次品18,样本次品率0.10909090909090909,似然值为-1.1039148885254946
# 170里有次品19,样本次品率0.11176470588235295,似然值为-0.9270834357771234
# 175里有次品20,样本次品率0.11428571428571428,似然值为-0.750251983028754
# 180里有次品21,样本次品率0.11666666666666667,似然值为-0.5734205302803836
# 185里有次品21,样本次品率0.11351351351351352,似然值为-0.8592125994801272
# 190里有次品21,样本次品率0.11052631578947368,似然值为-1.1450046686798707
# 195里有次品22,样本次品率0.11282051282051282,似然值为-0.9681732159315022
# 200里有次品23,样本次品率0.115,似然值为-0.7913417631831319
# 205里有次品24,样本次品率0.11707317073170732,似然值为-0.6145103104347616
# 210里有次品26,样本次品率0.12380952380952381,似然值为0.024944664261720817
# 215里有次品26,样本次品率0.12093023255813953,似然值为-0.2608474049380227
# 220里有次品26,样本次品率0.11818181818181818,似然值为-0.5466394741377663
# 225里有次品28,样本次品率0.12444444444444444,似然值为0.09281550055871612
# 230里有次品29,样本次品率0.12608695652173912,似然值为0.26964695330708643
# 235里有次品29,样本次品率0.12340425531914893,似然值为-0.016145115892657103
# 240里有次品29,样本次品率0.12083333333333333,似然值为-0.30193718509240064
# 245里有次品30,样本次品率0.12244897959183673,似然值为-0.12510573234403033
# 250里有次品30,样本次品率0.12,似然值为-0.41089780154377387
# 255里有次品30,样本次品率0.11764705882352941,似然值为-0.6966898707435174
# 260里有次品30,样本次品率0.11538461538461539,似然值为-0.9824819399432609
# 265里有次品30,样本次品率0.11320754716981132,似然值为-1.2682740091430045
# 270里有次品30,样本次品率0.1111111111111111,似然值为-1.5540660783427462
# 275里有次品30,样本次品率0.10909090909090909,似然值为-1.8398581475424898
# 280里有次品30,样本次品率0.10714285714285714,似然值为-2.1256502167422333
# 285里有次品31,样本次品率0.10877192982456141,似然值为-1.948818763993863
# 290里有次品31,样本次品率0.10689655172413794,似然值为-2.2346108331936048
# 295里有次品31,样本次品率0.10508474576271186,似然值为-2.5204029023933483
# 抽295,次品31,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品0,样本次品率0.0,似然值为-0.8573762075992295
# 20里有次品0,样本次品率0.0,似然值为-1.1431682767989728
# 25里有次品0,样本次品率0.0,似然值为-1.428960345998716
# 30里有次品0,样本次品率0.0,似然值为-1.714752415198459
# 35里有次品1,样本次品率0.02857142857142857,似然值为-1.5379209624500896
# 40里有次品1,样本次品率0.025,似然值为-1.8237130316498327
# 45里有次品3,样本次品率0.06666666666666667,似然值为-1.18425805695335
# 50里有次品4,样本次品率0.08,似然值为-1.0074266042049802
# 55里有次品4,样本次品率0.07272727272727272,似然值为-1.2932186734047237
# 60里有次品6,样本次品率0.1,似然值为-0.6537636987082411
# 65里有次品6,样本次品率0.09230769230769231,似然值为-0.9395557679079842
# 70里有次品6,样本次品率0.08571428571428572,似然值为-1.2253478371077273
# 75里有次品6,样本次品率0.08,似然值为-1.5111399063074704
# 80里有次品6,样本次品率0.075,似然值为-1.796931975507214
# 85里有次品8,样本次品率0.09411764705882353,似然值为-1.1574770008107316
# 90里有次品9,样本次品率0.1,似然值为-0.9806455480623617
# 95里有次品10,样本次品率0.10526315789473684,似然值为-0.8038140953139914
# 100里有次品11,样本次品率0.11,似然值为-0.6269826425656229
# 105里有次品11,样本次品率0.10476190476190476,似然值为-0.9127747117653655
# 110里有次品11,样本次品率0.1,似然值为-1.198566780965109
# 115里有次品11,样本次品率0.09565217391304348,似然值为-1.4843588501648517
# 120里有次品11,样本次品率0.09166666666666666,似然值为-1.7701509193645952
# 125里有次品11,样本次品率0.088,似然值为-2.0559429885643388
# 130里有次品11,样本次品率0.08461538461538462,似然值为-2.3417350577640814
# 抽130,次品11,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品2,样本次品率0.2,似然值为0.35366290549673934
# 15里有次品3,样本次品率0.2,似然值为0.530494358245109
# 20里有次品3,样本次品率0.15,似然值为0.24470228904536584
# 25里有次品3,样本次品率0.12,似然值为-0.04108978015437725
# 30里有次品3,样本次品率0.1,似然值为-0.32688184935412057
# 35里有次品3,样本次品率0.08571428571428572,似然值为-0.6126739185538637
# 40里有次品4,样本次品率0.1,似然值为-0.435842465805494
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品4,样本次品率0.08,似然值为-1.0074266042049802
# 55里有次品6,样本次品率0.10909090909090909,似然值为-0.3679716295084976
# 60里有次品7,样本次品率0.11666666666666667,似然值为-0.19114017676012818
# 65里有次品7,样本次品率0.1076923076923077,似然值为-0.47693224595987127
# 70里有次品8,样本次品率0.11428571428571428,似然值为-0.30010079321150185
# 75里有次品8,样本次品率0.10666666666666667,似然值为-0.5858928624112449
# 80里有次品8,样本次品率0.1,似然值为-0.871684931610988
# 85里有次品8,样本次品率0.09411764705882353,似然值为-1.1574770008107316
# 90里有次品8,样本次品率0.08888888888888889,似然值为-1.4432690700104742
# 95里有次品9,样本次品率0.09473684210526316,似然值为-1.2664376172621052
# 100里有次品9,样本次品率0.09,似然值为-1.552229686461848
# 105里有次品9,样本次品率0.08571428571428572,似然值为-1.8380217556615914
# 110里有次品10,样本次品率0.09090909090909091,似然值为-1.6611903029132211
# 115里有次品11,样本次品率0.09565217391304348,似然值为-1.4843588501648517
# 120里有次品11,样本次品率0.09166666666666666,似然值为-1.7701509193645952
# 125里有次品11,样本次品率0.088,似然值为-2.0559429885643388
# 130里有次品12,样本次品率0.09230769230769231,似然值为-1.8791115358159685
# 135里有次品14,样本次品率0.1037037037037037,似然值为-1.239656561119486
# 140里有次品14,样本次品率0.1,似然值为-1.5254486303192287
# 145里有次品15,样本次品率0.10344827586206896,似然值为-1.3486171775708602
# 150里有次品15,样本次品率0.1,似然值为-1.6344092467706028
# 155里有次品15,样本次品率0.0967741935483871,似然值为-1.9202013159703455
# 160里有次品15,样本次品率0.09375,似然值为-2.205993385170089
# 165里有次品15,样本次品率0.09090909090909091,似然值为-2.4917854543698326
# 抽165,次品15,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品2,样本次品率0.2,似然值为0.35366290549673934
# 15里有次品2,样本次品率0.13333333333333333,似然值为0.0678708362969962
# 20里有次品2,样本次品率0.1,似然值为-0.217921232902747
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品2,样本次品率0.06666666666666667,似然值为-0.7895053713022334
# 35里有次品3,样本次品率0.08571428571428572,似然值为-0.6126739185538637
# 40里有次品5,样本次品率0.125,似然值为0.026781056142619164
# 45里有次品7,样本次品率0.15555555555555556,似然值为0.6662360308391015
# 50里有次品7,样本次品率0.14,似然值为0.380443961639358
# 55里有次品9,样本次品率0.16363636363636364,似然值为1.0198989363358408
# 60里有次品11,样本次品率0.18333333333333332,似然值为1.6593539110323232
# 65里有次品11,样本次品率0.16923076923076924,似然值为1.3735618418325797
# 70里有次品12,样本次品率0.17142857142857143,似然值为1.55039329458095
# 75里有次品13,样本次品率0.17333333333333334,似然值为1.727224747329319
# 80里有次品13,样本次品率0.1625,似然值为1.4414326781295759
# 85里有次品13,样本次品率0.15294117647058825,似然值为1.1556406089298328
# 90里有次品13,样本次品率0.14444444444444443,似然值为0.8698485397300892
# 95里有次品13,样本次品率0.1368421052631579,似然值为0.5840564705303466
# 100里有次品14,样本次品率0.14,似然值为0.760887923278716
# 105里有次品15,样本次品率0.14285714285714285,似然值为0.9377193760270854
# 110里有次品15,样本次品率0.13636363636363635,似然值为0.6519273068273428
# 115里有次品15,样本次品率0.13043478260869565,似然值为0.36613523762759925
# 120里有次品16,样本次品率0.13333333333333333,似然值为0.5429666903759696
# 125里有次品16,样本次品率0.128,似然值为0.257174621176226
# 130里有次品17,样本次品率0.13076923076923078,似然值为0.43400607392459634
# 135里有次品17,样本次品率0.1259259259259259,似然值为0.1482140047248528
# 140里有次品18,样本次品率0.12857142857142856,似然值为0.3250454574732222
# 145里有次品18,样本次品率0.12413793103448276,似然值为0.039253388273478684
# 150里有次品18,样本次品率0.12,似然值为-0.24653868092626396
# 155里有次品19,样本次品率0.12258064516129032,似然值为-0.06970722817789454
# 160里有次品19,样本次品率0.11875,似然值为-0.3554992973776381
# 165里有次品19,样本次品率0.11515151515151516,似然值为-0.6412913665773798
# 170里有次品19,样本次品率0.11176470588235295,似然值为-0.9270834357771234
# 175里有次品19,样本次品率0.10857142857142857,似然值为-1.212875504976867
# 180里有次品19,样本次品率0.10555555555555556,似然值为-1.4986675741766105
# 185里有次品22,样本次品率0.11891891891891893,似然值为-0.3965890775320151
# 190里有次品22,样本次品率0.11578947368421053,似然值为-0.6823811467317586
# 195里有次品23,样本次品率0.11794871794871795,似然值为-0.5055496939833901
# 200里有次品24,样本次品率0.12,似然值为-0.328718241235018
# 205里有次品24,样本次品率0.11707317073170732,似然值为-0.6145103104347616
# 210里有次品25,样本次品率0.11904761904761904,似然值为-0.43767885768639303
# 215里有次品26,样本次品率0.12093023255813953,似然值为-0.2608474049380227
# 220里有次品26,样本次品率0.11818181818181818,似然值为-0.5466394741377663
# 225里有次品27,样本次品率0.12,似然值为-0.36980802138939595
# 230里有次品27,样本次品率0.11739130434782609,似然值为-0.6556000905891395
# 235里有次品28,样本次品率0.11914893617021277,似然值为-0.4787686378407692
# 240里有次品29,样本次品率0.12083333333333333,似然值为-0.30193718509240064
# 245里有次品29,样本次品率0.11836734693877551,似然值为-0.5877292542921442
# 250里有次品29,样本次品率0.116,似然值为-0.8735213234918859
# 255里有次品29,样本次品率0.11372549019607843,似然值为-1.1593133926916295
# 260里有次品31,样本次品率0.11923076923076924,似然值为-0.5198584179951471
# 265里有次品31,样本次品率0.1169811320754717,似然值为-0.8056504871948889
# 270里有次品31,样本次品率0.11481481481481481,似然值为-1.0914425563946324
# 275里有次品31,样本次品率0.11272727272727273,似然值为-1.377234625594376
# 280里有次品31,样本次品率0.11071428571428571,似然值为-1.6630266947941195
# 285里有次品31,样本次品率0.10877192982456141,似然值为-1.948818763993863
# 290里有次品31,样本次品率0.10689655172413794,似然值为-2.2346108331936048
# 295里有次品32,样本次品率0.10847457627118644,似然值为-2.0577793804452362
# 300里有次品33,样本次品率0.11,似然值为-1.8809479276968677
# 305里有次品34,样本次品率0.11147540983606558,似然值为-1.7041164749484956
# 310里有次品34,样本次品率0.10967741935483871,似然值为-1.9899085441482391
# 315里有次品34,样本次品率0.10793650793650794,似然值为-2.2757006133479827
# 抽315,次品34,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品2,样本次品率0.13333333333333333,似然值为0.0678708362969962
# 20里有次品3,样本次品率0.15,似然值为0.24470228904536584
# 25里有次品3,样本次品率0.12,似然值为-0.04108978015437725
# 30里有次品4,样本次品率0.13333333333333333,似然值为0.1357416725939924
# 35里有次品4,样本次品率0.11428571428571428,似然值为-0.15005039660575092
# 40里有次品4,样本次品率0.1,似然值为-0.435842465805494
# 45里有次品5,样本次品率0.1111111111111111,似然值为-0.2590110130571244
# 50里有次品7,样本次品率0.14,似然值为0.380443961639358
# 55里有次品7,样本次品率0.12727272727272726,似然值为0.09465189243961492
# 60里有次品7,样本次品率0.11666666666666667,似然值为-0.19114017676012818
# 65里有次品7,样本次品率0.1076923076923077,似然值为-0.47693224595987127
# 70里有次品7,样本次品率0.1,似然值为-0.7627243151596144
# 75里有次品7,样本次品率0.09333333333333334,似然值为-1.048516384359358
# 80里有次品7,样本次品率0.0875,似然值为-1.3343084535591005
# 85里有次品9,样本次品率0.10588235294117647,似然值为-0.6948534788626182
# 90里有次品9,样本次品率0.1,似然值为-0.9806455480623617
# 95里有次品9,样本次品率0.09473684210526316,似然值为-1.2664376172621052
# 100里有次品9,样本次品率0.09,似然值为-1.552229686461848
# 105里有次品10,样本次品率0.09523809523809523,似然值为-1.3753982337134776
# 110里有次品11,样本次品率0.1,似然值为-1.198566780965109
# 115里有次品11,样本次品率0.09565217391304348,似然值为-1.4843588501648517
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品14,样本次品率0.112,似然值为-0.6680724227199999
# 130里有次品15,样本次品率0.11538461538461539,似然值为-0.49124096997163047
# 135里有次品16,样本次品率0.11851851851851852,似然值为-0.31440951722326016
# 140里有次品17,样本次品率0.12142857142857143,似然值为-0.13757806447488985
# 145里有次品18,样本次品率0.12413793103448276,似然值为0.039253388273478684
# 150里有次品18,样本次品率0.12,似然值为-0.24653868092626396
# 155里有次品18,样本次品率0.11612903225806452,似然值为-0.5323307501260075
# 160里有次品18,样本次品率0.1125,似然值为-0.818122819325751
# 165里有次品18,样本次品率0.10909090909090909,似然值为-1.1039148885254946
# 170里有次品18,样本次品率0.10588235294117647,似然值为-1.3897069577252363
# 175里有次品18,样本次品率0.10285714285714286,似然值为-1.6754990269249799
# 180里有次品19,样本次品率0.10555555555555556,似然值为-1.4986675741766105
# 185里有次品21,样本次品率0.11351351351351352,似然值为-0.8592125994801272
# 190里有次品21,样本次品率0.11052631578947368,似然值为-1.1450046686798707
# 195里有次品24,样本次品率0.12307692307692308,似然值为-0.04292617203527449
# 200里有次品24,样本次品率0.12,似然值为-0.328718241235018
# 205里有次品24,样本次品率0.11707317073170732,似然值为-0.6145103104347616
# 210里有次品24,样本次品率0.11428571428571428,似然值为-0.9003023796345051
# 215里有次品24,样本次品率0.11162790697674418,似然值为-1.1860944488342486
# 220里有次品24,样本次品率0.10909090909090909,似然值为-1.4718865180339904
# 225里有次品24,样本次品率0.10666666666666667,似然值为-1.757678587233734
# 230里有次品24,样本次品率0.10434782608695652,似然值为-2.0434706564334775
# 235里有次品24,样本次品率0.10212765957446808,似然值为-2.329262725633221
# 抽235,次品24,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品2,样本次品率0.4,似然值为0.6394549746964825
# 10里有次品2,样本次品率0.2,似然值为0.35366290549673934
# 15里有次品3,样本次品率0.2,似然值为0.530494358245109
# 20里有次品4,样本次品率0.2,似然值为0.7073258109934787
# 25里有次品4,样本次品率0.16,似然值为0.4215337417937355
# 30里有次品5,样本次品率0.16666666666666666,似然值为0.5983651945421053
# 35里有次品6,样本次品率0.17142857142857143,似然值为0.775196647290475
# 40里有次品6,样本次品率0.15,似然值为0.4894045780907317
# 45里有次品7,样本次品率0.15555555555555556,似然值为0.6662360308391015
# 50里有次品8,样本次品率0.16,似然值为0.843067483587471
# 55里有次品9,样本次品率0.16363636363636364,似然值为1.0198989363358408
# 60里有次品10,样本次品率0.16666666666666666,似然值为1.1967303890842107
# 65里有次品11,样本次品率0.16923076923076924,似然值为1.3735618418325797
# 70里有次品11,样本次品率0.15714285714285714,似然值为1.0877697726328366
# 75里有次品11,样本次品率0.14666666666666667,似然值为0.8019777034330935
# 80里有次品11,样本次品率0.1375,似然值为0.5161856342333504
# 85里有次品12,样本次品率0.1411764705882353,似然值为0.6930170869817207
# 90里有次品12,样本次品率0.13333333333333333,似然值为0.40722501778197717
# 95里有次品12,样本次品率0.12631578947368421,似然值为0.12143294858223364
# 100里有次品12,样本次品率0.12,似然值为-0.164359120617509
# 105里有次品12,样本次品率0.11428571428571428,似然值为-0.45015118981725255
# 110里有次品13,样本次品率0.11818181818181818,似然值为-0.27331973706888313
# 115里有次品14,样本次品率0.12173913043478261,似然值为-0.09648828432051282
# 120里有次品14,样本次品率0.11666666666666667,似然值为-0.38228035352025636
# 125里有次品14,样本次品率0.112,似然值为-0.6680724227199999
# 130里有次品14,样本次品率0.1076923076923077,似然值为-0.9538644919197425
# 135里有次品15,样本次品率0.1111111111111111,似然值为-0.7770330391713731
# 140里有次品15,样本次品率0.10714285714285714,似然值为-1.0628251083711167
# 145里有次品15,样本次品率0.10344827586206896,似然值为-1.3486171775708602
# 150里有次品16,样本次品率0.10666666666666667,似然值为-1.1717857248224899
# 155里有次品16,样本次品率0.1032258064516129,似然值为-1.4575777940222334
# 160里有次品16,样本次品率0.1,似然值为-1.743369863221976
# 165里有次品16,样本次品率0.09696969696969697,似然值为-2.0291619324217196
# 170里有次品16,样本次品率0.09411764705882353,似然值为-2.314954001621463
# 抽170,次品16,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品2,样本次品率0.13333333333333333,似然值为0.0678708362969962
# 20里有次品3,样本次品率0.15,似然值为0.24470228904536584
# 25里有次品3,样本次品率0.12,似然值为-0.04108978015437725
# 30里有次品4,样本次品率0.13333333333333333,似然值为0.1357416725939924
# 35里有次品5,样本次品率0.14285714285714285,似然值为0.31257312534236226
# 40里有次品5,样本次品率0.125,似然值为0.026781056142619164
# 45里有次品5,样本次品率0.1111111111111111,似然值为-0.2590110130571244
# 50里有次品6,样本次品率0.12,似然值为-0.0821795603087545
# 55里有次品6,样本次品率0.10909090909090909,似然值为-0.3679716295084976
# 60里有次品8,样本次品率0.13333333333333333,似然值为0.2714833451879848
# 65里有次品8,样本次品率0.12307692307692308,似然值为-0.014308724011758756
# 70里有次品8,样本次品率0.11428571428571428,似然值为-0.30010079321150185
# 75里有次品9,样本次品率0.12,似然值为-0.12326934046313198
# 80里有次品10,样本次品率0.125,似然值为0.05356211228523833
# 85里有次品10,样本次品率0.11764705882352941,似然值为-0.2322299569145052
# 90里有次品10,样本次品率0.1111111111111111,似然值为-0.5180220261142487
# 95里有次品10,样本次品率0.10526315789473684,似然值为-0.8038140953139914
# 100里有次品10,样本次品率0.1,似然值为-1.089606164513735
# 105里有次品10,样本次品率0.09523809523809523,似然值为-1.3753982337134776
# 110里有次品11,样本次品率0.1,似然值为-1.198566780965109
# 115里有次品11,样本次品率0.09565217391304348,似然值为-1.4843588501648517
# 120里有次品12,样本次品率0.1,似然值为-1.3075273974164823
# 125里有次品12,样本次品率0.096,似然值为-1.593319466616225
# 130里有次品12,样本次品率0.09230769230769231,似然值为-1.8791115358159685
# 135里有次品12,样本次品率0.08888888888888889,似然值为-2.164903605015711
# 140里有次品13,样本次品率0.09285714285714286,似然值为-1.9880721522673426
# 145里有次品14,样本次品率0.09655172413793103,似然值为-1.8112406995189723
# 150里有次品15,样本次品率0.1,似然值为-1.6344092467706028
# 155里有次品15,样本次品率0.0967741935483871,似然值为-1.9202013159703455
# 160里有次品16,样本次品率0.1,似然值为-1.743369863221976
# ...
# 245里有次品29,样本次品率0.11836734693877551,似然值为-0.5877292542921442
# 250里有次品30,样本次品率0.12,似然值为-0.41089780154377387
# 255里有次品31,样本次品率0.12156862745098039,似然值为-0.23406634879540356
# 260里有次品31,样本次品率0.11923076923076924,似然值为-0.5198584179951471
# 265里有次品33,样本次品率0.12452830188679245,似然值为0.11959655670133529
# 270里有次品33,样本次品率0.12222222222222222,似然值为-0.16619551249840825
# 275里有次品33,样本次品率0.12,似然值为-0.4519875816981518
# 280里有次品33,样本次品率0.11785714285714285,似然值为-0.7377796508978953
# 285里有次品34,样本次品率0.11929824561403508,似然值为-0.5609481981495232
# 290里有次品34,样本次品率0.11724137931034483,似然值为-0.8467402673492668
# 295里有次品34,样本次品率0.1152542372881356,似然值为-1.1325323365490103
# 300里有次品36,样本次品率0.12,似然值为-0.49307736185252793
# 305里有次品37,样本次品率0.12131147540983607,似然值为-0.3162459091041594
# 310里有次品37,样本次品率0.11935483870967742,似然值为-0.6020379783039029
# 315里有次品37,样本次品率0.11746031746031746,似然值为-0.8878300475036465
# 320里有次品39,样本次品率0.121875,似然值为-0.2483750728071623
# 325里有次品39,样本次品率0.12,似然值为-0.5341671420069058
# 330里有次品40,样本次品率0.12121212121212122,似然值为-0.35733568925853376
# 335里有次品40,样本次品率0.11940298507462686,似然值为-0.6431277584582773
# 340里有次品40,样本次品率0.11764705882352941,似然值为-0.9289198276580208
# 345里有次品41,样本次品率0.11884057971014493,似然值为-0.7520883749096505
# 350里有次品42,样本次品率0.12,似然值为-0.5752569221612838
# 355里有次品43,样本次品率0.12112676056338029,似然值为-0.39842546941291346
# 360里有次品43,样本次品率0.11944444444444445,似然值为-0.684217538612657
# 365里有次品43,样本次品率0.1178082191780822,似然值为-0.9700096078124005
# 370里有次品43,样本次品率0.11621621621621622,似然值为-1.255801677012144
# 375里有次品43,样本次品率0.11466666666666667,似然值为-1.5415937462118876
# 380里有次品44,样本次品率0.11578947368421053,似然值为-1.3647622934635173
# 385里有次品44,样本次品率0.11428571428571428,似然值为-1.6505543626632608
# 390里有次品44,样本次品率0.11282051282051282,似然值为-1.9363464318630044
# 395里有次品45,样本次品率0.11392405063291139,似然值为-1.759514979114634
# 400里有次品48,样本次品率0.12,似然值为-0.657436482470036
# 405里有次品48,样本次品率0.11851851851851852,似然值为-0.9432285516697796
# 410里有次品48,样本次品率0.11707317073170732,似然值为-1.2290206208695231
# 415里有次品49,样本次品率0.1180722891566265,似然值为-1.0521891681211528
# 420里有次品49,样本次品率0.11666666666666667,似然值为-1.3379812373208964
# 425里有次品49,样本次品率0.11529411764705882,似然值为-1.62377330652064
# 430里有次品50,样本次品率0.11627906976744186,似然值为-1.4469418537722696
# 435里有次品51,样本次品率0.11724137931034483,似然值为-1.2701104010239028
# 440里有次品52,样本次品率0.11818181818181818,似然值为-1.0932789482755325
# 445里有次品52,样本次品率0.11685393258426967,似然值为-1.379071017475276
# 450里有次品52,样本次品率0.11555555555555555,似然值为-1.6648630866750196
# 455里有次品53,样本次品率0.11648351648351649,似然值为-1.4880316339266493
# 460里有次品53,样本次品率0.11521739130434783,似然值为-1.7738237031263928
# 465里有次品53,样本次品率0.11397849462365592,似然值为-2.0596157723261364
# 470里有次品53,样本次品率0.1127659574468085,似然值为-2.34540784152588
# 抽470,次品53,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品0,样本次品率0.0,似然值为-0.8573762075992295
# 20里有次品0,样本次品率0.0,似然值为-1.1431682767989728
# 25里有次品0,样本次品率0.0,似然值为-1.428960345998716
# 30里有次品0,样本次品率0.0,似然值为-1.714752415198459
# 35里有次品0,样本次品率0.0,似然值为-2.000544484398202
# 40里有次品0,样本次品率0.0,似然值为-2.2863365535979456
# 抽40,次品0,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品2,样本次品率0.2,似然值为0.35366290549673934
# 15里有次品2,样本次品率0.13333333333333333,似然值为0.0678708362969962
# 20里有次品3,样本次品率0.15,似然值为0.24470228904536584
# 25里有次品5,样本次品率0.2,似然值为0.8841572637418484
# 30里有次品5,样本次品率0.16666666666666666,似然值为0.5983651945421053
# 35里有次品5,样本次品率0.14285714285714285,似然值为0.31257312534236226
# 40里有次品8,样本次品率0.2,似然值为1.4146516219869574
# 45里有次品9,样本次品率0.2,似然值为1.591483074735327
# 50里有次品9,样本次品率0.18,似然值为1.305691005535584
# 55里有次品9,样本次品率0.16363636363636364,似然值为1.0198989363358408
# 60里有次品10,样本次品率0.16666666666666666,似然值为1.1967303890842107
# 65里有次品11,样本次品率0.16923076923076924,似然值为1.3735618418325797
# 70里有次品12,样本次品率0.17142857142857143,似然值为1.55039329458095
# 75里有次品12,样本次品率0.16,似然值为1.264601225381207
# 80里有次品12,样本次品率0.15,似然值为0.9788091561814634
# 85里有次品12,样本次品率0.1411764705882353,似然值为0.6930170869817207
# 90里有次品12,样本次品率0.13333333333333333,似然值为0.40722501778197717
# 95里有次品12,样本次品率0.12631578947368421,似然值为0.12143294858223364
# 100里有次品12,样本次品率0.12,似然值为-0.164359120617509
# 105里有次品12,样本次品率0.11428571428571428,似然值为-0.45015118981725255
# 110里有次品12,样本次品率0.10909090909090909,似然值为-0.7359432590169952
# 115里有次品12,样本次品率0.10434782608695652,似然值为-1.0217353282167387
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品13,样本次品率0.104,似然值为-1.1306959446681129
# 130里有次品13,样本次品率0.1,似然值为-1.4164880138678555
# 135里有次品13,样本次品率0.0962962962962963,似然值为-1.702280083067599
# 140里有次品13,样本次品率0.09285714285714286,似然值为-1.9880721522673426
# 145里有次品15,样本次品率0.10344827586206896,似然值为-1.3486171775708602
# 150里有次品16,样本次品率0.10666666666666667,似然值为-1.1717857248224899
# 155里有次品16,样本次品率0.1032258064516129,似然值为-1.4575777940222334
# 160里有次品16,样本次品率0.1,似然值为-1.743369863221976
# 165里有次品16,样本次品率0.09696969696969697,似然值为-2.0291619324217196
# 170里有次品17,样本次品率0.1,似然值为-1.8523304796733502
# 175里有次品17,样本次品率0.09714285714285714,似然值为-2.138122548873092
# 180里有次品17,样本次品率0.09444444444444444,似然值为-2.4239146180728355
# 抽180,次品17,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品1,样本次品率0.05,似然值为-0.6805447548508599
# 25里有次品1,样本次品率0.04,似然值为-0.9663368240506032
# 30里有次品1,样本次品率0.03333333333333333,似然值为-1.2521288932503463
# 35里有次品1,样本次品率0.02857142857142857,似然值为-1.5379209624500896
# 40里有次品1,样本次品率0.025,似然值为-1.8237130316498327
# 45里有次品1,样本次品率0.022222222222222223,似然值为-2.1095051008495758
# 50里有次品1,样本次品率0.02,似然值为-2.395297170049319
# 抽50,次品1,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品3,样本次品率0.6,似然值为1.1020784966445953
# 10里有次品3,样本次品率0.3,似然值为0.8162864274448522
# 15里有次品4,样本次品率0.26666666666666666,似然值为0.9931178801932219
# 20里有次品5,样本次品率0.25,似然值为1.1699493329415918
# 25里有次品5,样本次品率0.2,似然值为0.8841572637418484
# 30里有次品6,样本次品率0.2,似然值为1.060988716490218
# 35里有次品7,样本次品率0.2,似然值为1.2378201692385877
# 40里有次品7,样本次品率0.175,似然值为0.9520281000388446
# 45里有次品7,样本次品率0.15555555555555556,似然值为0.6662360308391015
# 50里有次品7,样本次品率0.14,似然值为0.380443961639358
# 55里有次品7,样本次品率0.12727272727272726,似然值为0.09465189243961492
# 60里有次品8,样本次品率0.13333333333333333,似然值为0.2714833451879848
# 65里有次品8,样本次品率0.12307692307692308,似然值为-0.014308724011758756
# 70里有次品8,样本次品率0.11428571428571428,似然值为-0.30010079321150185
# 75里有次品9,样本次品率0.12,似然值为-0.12326934046313198
# 80里有次品10,样本次品率0.125,似然值为0.05356211228523833
# 85里有次品11,样本次品率0.12941176470588237,似然值为0.23039356503360686
# 90里有次品11,样本次品率0.12222222222222222,似然值为-0.05539850416613579
# 95里有次品13,样本次品率0.1368421052631579,似然值为0.5840564705303466
# 100里有次品13,样本次品率0.13,似然值为0.29826440133060306
# 105里有次品14,样本次品率0.13333333333333333,似然值为0.47509585407897337
# 110里有次品15,样本次品率0.13636363636363635,似然值为0.6519273068273428
# 115里有次品15,样本次品率0.13043478260869565,似然值为0.36613523762759925
# 120里有次品15,样本次品率0.125,似然值为0.08034316842785572
# 125里有次品16,样本次品率0.128,似然值为0.257174621176226
# 130里有次品16,样本次品率0.12307692307692308,似然值为-0.02861744802351751
# 135里有次品17,样本次品率0.1259259259259259,似然值为0.1482140047248528
# 140里有次品17,样本次品率0.12142857142857143,似然值为-0.13757806447488985
# 145里有次品18,样本次品率0.12413793103448276,似然值为0.039253388273478684
# 150里有次品20,样本次品率0.13333333333333333,似然值为0.678708362969962
# 155里有次品20,样本次品率0.12903225806451613,似然值为0.3929162937702193
# 160里有次品20,样本次品率0.125,似然值为0.10712422457047666
# 165里有次品21,样本次品率0.12727272727272726,似然值为0.2839556773188452
# 170里有次品21,样本次品率0.12352941176470589,似然值为-0.001836391880898347
# 175里有次品21,样本次品率0.12,似然值为-0.2876284610806419
# 180里有次品21,样本次品率0.11666666666666667,似然值为-0.5734205302803836
# 185里有次品21,样本次品率0.11351351351351352,似然值为-0.8592125994801272
# 190里有次品22,样本次品率0.11578947368421053,似然值为-0.6823811467317586
# 195里有次品22,样本次品率0.11282051282051282,似然值为-0.9681732159315022
# 200里有次品22,样本次品率0.11,似然值为-1.2539652851312457
# 205里有次品23,样本次品率0.11219512195121951,似然值为-1.0771338323828754
# 210里有次品24,样本次品率0.11428571428571428,似然值为-0.9003023796345051
# 215里有次品24,样本次品率0.11162790697674418,似然值为-1.1860944488342486
# 220里有次品24,样本次品率0.10909090909090909,似然值为-1.4718865180339904
# 225里有次品25,样本次品率0.1111111111111111,似然值为-1.2950550652856219
# 230里有次品25,样本次品率0.10869565217391304,似然值为-1.5808471344853654
# 235里有次品25,样本次品率0.10638297872340426,似然值为-1.866639203685109
# 240里有次品25,样本次品率0.10416666666666667,似然值为-2.1524312728848507
# 245里有次品26,样本次品率0.10612244897959183,似然值为-1.9755998201364822
# 250里有次品27,样本次品率0.108,似然值为-1.7987683673881119
# 255里有次品27,样本次品率0.10588235294117647,似然值为-2.0845604365878554
# 260里有次品28,样本次品率0.1076923076923077,似然值为-1.907728983839485
# 265里有次品28,样本次品率0.10566037735849057,似然值为-2.1935210530392286
# 270里有次品28,样本次品率0.1037037037037037,似然值为-2.479313122238972
# 抽270,次品28,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品1,样本次品率0.05,似然值为-0.6805447548508599
# 25里有次品2,样本次品率0.08,似然值为-0.5037133021024901
# 30里有次品3,样本次品率0.1,似然值为-0.32688184935412057
# 35里有次品3,样本次品率0.08571428571428572,似然值为-0.6126739185538637
# 40里有次品4,样本次品率0.1,似然值为-0.435842465805494
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品5,样本次品率0.1,似然值为-0.5448030822568675
# 55里有次品6,样本次品率0.10909090909090909,似然值为-0.3679716295084976
# 60里有次品6,样本次品率0.1,似然值为-0.6537636987082411
# 65里有次品6,样本次品率0.09230769230769231,似然值为-0.9395557679079842
# 70里有次品6,样本次品率0.08571428571428572,似然值为-1.2253478371077273
# 75里有次品6,样本次品率0.08,似然值为-1.5111399063074704
# 80里有次品7,样本次品率0.0875,似然值为-1.3343084535591005
# 85里有次品8,样本次品率0.09411764705882353,似然值为-1.1574770008107316
# 90里有次品9,样本次品率0.1,似然值为-0.9806455480623617
# 95里有次品9,样本次品率0.09473684210526316,似然值为-1.2664376172621052
# 100里有次品9,样本次品率0.09,似然值为-1.552229686461848
# 105里有次品9,样本次品率0.08571428571428572,似然值为-1.8380217556615914
# 110里有次品9,样本次品率0.08181818181818182,似然值为-2.123813824861334
# 115里有次品9,样本次品率0.0782608695652174,似然值为-2.4096058940610776
# 抽115,次品9,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品1,样本次品率0.2,似然值为0.17683145274836967
# 10里有次品1,样本次品率0.1,似然值为-0.1089606164513735
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品1,样本次品率0.05,似然值为-0.6805447548508599
# 25里有次品1,样本次品率0.04,似然值为-0.9663368240506032
# 30里有次品1,样本次品率0.03333333333333333,似然值为-1.2521288932503463
# 35里有次品2,样本次品率0.05714285714285714,似然值为-1.0752974405019766
# 40里有次品3,样本次品率0.075,似然值为-0.898465987753607
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品5,样本次品率0.1,似然值为-0.5448030822568675
# 55里有次品6,样本次品率0.10909090909090909,似然值为-0.3679716295084976
# 60里有次品7,样本次品率0.11666666666666667,似然值为-0.19114017676012818
# 65里有次品8,样本次品率0.12307692307692308,似然值为-0.014308724011758756
# 70里有次品8,样本次品率0.11428571428571428,似然值为-0.30010079321150185
# 75里有次品8,样本次品率0.10666666666666667,似然值为-0.5858928624112449
# 80里有次品10,样本次品率0.125,似然值为0.05356211228523833
# 85里有次品11,样本次品率0.12941176470588237,似然值为0.23039356503360686
# 90里有次品12,样本次品率0.13333333333333333,似然值为0.40722501778197717
# 95里有次品12,样本次品率0.12631578947368421,似然值为0.12143294858223364
# 100里有次品13,样本次品率0.13,似然值为0.29826440133060306
# 105里有次品14,样本次品率0.13333333333333333,似然值为0.47509585407897337
# 110里有次品15,样本次品率0.13636363636363635,似然值为0.6519273068273428
# 115里有次品15,样本次品率0.13043478260869565,似然值为0.36613523762759925
# 120里有次品15,样本次品率0.125,似然值为0.08034316842785572
# 125里有次品15,样本次品率0.12,似然值为-0.20544890077188693
# 130里有次品16,样本次品率0.12307692307692308,似然值为-0.02861744802351751
# 135里有次品16,样本次品率0.11851851851851852,似然值为-0.31440951722326016
# 140里有次品16,样本次品率0.11428571428571428,似然值为-0.6002015864230037
# 145里有次品16,样本次品率0.1103448275862069,似然值为-0.8859936556227463
# 150里有次品16,样本次品率0.10666666666666667,似然值为-1.1717857248224899
# 155里有次品16,样本次品率0.1032258064516129,似然值为-1.4575777940222334
# 160里有次品16,样本次品率0.1,似然值为-1.743369863221976
# 165里有次品16,样本次品率0.09696969696969697,似然值为-2.0291619324217196
# 170里有次品17,样本次品率0.1,似然值为-1.8523304796733502
# 175里有次品18,样本次品率0.10285714285714286,似然值为-1.6754990269249799
# 180里有次品20,样本次品率0.1111111111111111,似然值为-1.0360440522284975
# 185里有次品22,样本次品率0.11891891891891893,似然值为-0.3965890775320151
# 190里有次品23,样本次品率0.12105263157894737,似然值为-0.21975762478364658
# 195里有次品24,样本次品率0.12307692307692308,似然值为-0.04292617203527449
# 200里有次品26,样本次品率0.13,似然值为0.5965288026612061
# 205里有次品27,样本次品率0.13170731707317074,似然值为0.7733602554095764
# 210里有次品29,样本次品率0.1380952380952381,似然值为1.4128152301060588
# 215里有次品30,样本次品率0.13953488372093023,似然值为1.5896466828544273
# 220里有次品31,样本次品率0.1409090909090909,似然值为1.7664781356027994
# 225里有次品32,样本次品率0.14222222222222222,似然值为1.943309588351168
# 230里有次品33,样本次品率0.14347826086956522,似然值为2.1201410410995365
# 235里有次品33,样本次品率0.14042553191489363,似然值为1.8343489718997947
# 240里有次品33,样本次品率0.1375,似然值为1.5485569027000512
# 245里有次品33,样本次品率0.1346938775510204,似然值为1.2627648335003077
# 250里有次品33,样本次品率0.132,似然值为0.9769727643005641
# 255里有次品35,样本次品率0.13725490196078433,似然值为1.6164277389970483
# 260里有次品35,样本次品率0.1346153846153846,似然值为1.3306356697973047
# 265里有次品36,样本次品率0.13584905660377358,似然值为1.5074671225456733
# 270里有次品36,样本次品率0.13333333333333333,似然值为1.2216750533459315
# 275里有次品36,样本次品率0.13090909090909092,似然值为0.935882984146188
# 280里有次品36,样本次品率0.12857142857142856,似然值为0.6500909149464444
# 285里有次品37,样本次品率0.12982456140350876,似然值为0.826922367694813
# 290里有次品37,样本次品率0.12758620689655173,似然值为0.5411302984950694
# 295里有次品38,样本次品率0.1288135593220339,似然值为0.7179617512434415
# 300里有次品38,样本次品率0.12666666666666668,似然值为0.432169682043698
# 305里有次品38,样本次品率0.12459016393442623,似然值为0.14637761284395445
# 310里有次品38,样本次品率0.12258064516129032,似然值为-0.13941445635578908
# 315里有次品38,样本次品率0.12063492063492064,似然值为-0.42520652555553085
# 320里有次品38,样本次品率0.11875,似然值为-0.7109985947552762
# 325里有次品39,样本次品率0.12,似然值为-0.5341671420069058
# 330里有次品39,样本次品率0.11818181818181818,似然值为-0.8199592112066494
# 335里有次品39,样本次品率0.11641791044776119,似然值为-1.105751280406393
# 340里有次品40,样本次品率0.11764705882352941,似然值为-0.9289198276580208
# 345里有次品40,样本次品率0.11594202898550725,似然值为-1.2147118968577644
# 350里有次品42,样本次品率0.12,似然值为-0.5752569221612838
# 355里有次品42,样本次品率0.11830985915492957,似然值为-0.8610489913610273
# 360里有次品43,样本次品率0.11944444444444445,似然值为-0.684217538612657
# 365里有次品43,样本次品率0.1178082191780822,似然值为-0.9700096078124005
# 370里有次品43,样本次品率0.11621621621621622,似然值为-1.255801677012144
# 375里有次品44,样本次品率0.11733333333333333,似然值为-1.0789702242637738
# 380里有次品44,样本次品率0.11578947368421053,似然值为-1.3647622934635173
# 385里有次品44,样本次品率0.11428571428571428,似然值为-1.6505543626632608
# 390里有次品44,样本次品率0.11282051282051282,似然值为-1.9363464318630044
# 395里有次品44,样本次品率0.11139240506329114,似然值为-2.222138501062748
# 400里有次品45,样本次品率0.1125,似然值为-2.0453070483143776
# 405里有次品45,样本次品率0.1111111111111111,似然值为-2.331099117514121
# 抽405,次品45,接受这批零件
# 似然边界为-2.251291798606495 ~ 2.8903717578961645
# 5里有次品0,样本次品率0.0,似然值为-0.2857920691997432
# 10里有次品0,样本次品率0.0,似然值为-0.5715841383994864
# 15里有次品1,样本次品率0.06666666666666667,似然值为-0.3947526856511167
# 20里有次品2,样本次品率0.1,似然值为-0.217921232902747
# 25里有次品3,样本次品率0.12,似然值为-0.04108978015437725
# 30里有次品3,样本次品率0.1,似然值为-0.32688184935412057
# 35里有次品3,样本次品率0.08571428571428572,似然值为-0.6126739185538637
# 40里有次品4,样本次品率0.1,似然值为-0.435842465805494
# 45里有次品4,样本次品率0.08888888888888889,似然值为-0.7216345350052371
# 50里有次品5,样本次品率0.1,似然值为-0.5448030822568675
# 55里有次品6,样本次品率0.10909090909090909,似然值为-0.3679716295084976
# 60里有次品6,样本次品率0.1,似然值为-0.6537636987082411
# 65里有次品7,样本次品率0.1076923076923077,似然值为-0.47693224595987127
# 70里有次品7,样本次品率0.1,似然值为-0.7627243151596144
# 75里有次品7,样本次品率0.09333333333333334,似然值为-1.048516384359358
# 80里有次品8,样本次品率0.1,似然值为-0.871684931610988
# 85里有次品10,样本次品率0.11764705882352941,似然值为-0.2322299569145052
# 90里有次品10,样本次品率0.1111111111111111,似然值为-0.5180220261142487
# 95里有次品11,样本次品率0.11578947368421053,似然值为-0.3411905733658793
# 100里有次品11,样本次品率0.11,似然值为-0.6269826425656229
# 105里有次品12,样本次品率0.11428571428571428,似然值为-0.45015118981725255
# 110里有次品12,样本次品率0.10909090909090909,似然值为-0.7359432590169952
# 115里有次品13,样本次品率0.11304347826086956,似然值为-0.5591118062686267
# 120里有次品13,样本次品率0.10833333333333334,似然值为-0.8449038754683693
# 125里有次品13,样本次品率0.104,似然值为-1.1306959446681129
# 130里有次品14,样本次品率0.1076923076923077,似然值为-0.9538644919197425
# 135里有次品16,样本次品率0.11851851851851852,似然值为-0.31440951722326016
# 140里有次品17,样本次品率0.12142857142857143,似然值为-0.13757806447488985
# 145里有次品17,样本次品率0.11724137931034483,似然值为-0.4233701336746334
# 150里有次品17,样本次品率0.11333333333333333,似然值为-0.7091622028743769
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
